# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("pilot2_processed.csv")

# %%
df
# Out:
#       Unnamed: 0  run_id stress stable block_no  block  trial_no  b1  b2  b3  \
# 0              1      26     no     no      b04      1         1 -10  13  44
# 1              2      26     no     no      b04      1         2  11  11  26
# 2              3      26     no     no      b04      1         3   0   2  20
# 3              4      26     no     no      b04      1         4   3  14  -4
# 4              5      26     no     no      b04      1         5  21  20   9
# ...          ...     ...    ...    ...      ...    ...       ...  ..  ..  ..
# 4795        4796     213     no    yes      b13      4        46 -15  -3  20
# 4796        4797     213     no    yes      b13      4        47 -23 -10  13
# 4797        4798     213     no    yes      b13      4        48 -15  -2   6
# 4798        4799     213     no    yes      b13      4        49 -18  -8   3
# 4799        4800     213     no    yes      b13      4        50 -13  -1   9
#
#       b4  resp  advantageous  switch
# ...

# %%
df.stress
# Out:
# 0       no
# 1       no
# 2       no
# 3       no
# 4       no
#         ..
# 4795    no
# 4796    no
# 4797    no
# 4798    no
# 4799    no
# Name: stress, Length: 4800, dtype: object

# %%
df[['stable','stress']]
# Out:
#      stable stress
# 0        no     no
# 1        no     no
# 2        no     no
# 3        no     no
# 4        no     no
# ...     ...    ...
# 4795    yes     no
# 4796    yes     no
# 4797    yes     no
# 4798    yes     no
# 4799    yes     no
#
# [4800 rows x 2 columns]

# %%
df.shape
# Out:
# (4800, 14)

# %%
df.loc[1]
# Out:
# Unnamed: 0        2
# run_id           26
# stress           no
# stable           no
# block_no        b04
# block             1
# trial_no          2
# b1               11
# b2               11
# b3               26
# b4              -14
# resp              1
# advantageous      0
# switch          0.0
# Name: 1, dtype: object

# %%
df[df['switch'] == 0]
# Out:
#       Unnamed: 0  run_id stress stable block_no  block  trial_no  b1  b2  b3  \
# 1              2      26     no     no      b04      1         2  11  11  26
# 3              4      26     no     no      b04      1         4   3  14  -4
# 5              6      26     no     no      b04      1         6  50  35  26
# 8              9      26     no     no      b04      1         9  52  27   5
# 9             10      26     no     no      b04      1        10  46  35  23
# ...          ...     ...    ...    ...      ...    ...       ...  ..  ..  ..
# 4795        4796     213     no    yes      b13      4        46 -15  -3  20
# 4796        4797     213     no    yes      b13      4        47 -23 -10  13
# 4797        4798     213     no    yes      b13      4        48 -15  -2   6
# 4798        4799     213     no    yes      b13      4        49 -18  -8   3
# 4799        4800     213     no    yes      b13      4        50 -13  -1   9
#
#       b4  resp  advantageous  switch
# ...

# %%
df[df['block'] == 1]
# Out:
#       Unnamed: 0  run_id stress stable block_no  block  trial_no  b1  b2  b3  \
# 0              1      26     no     no      b04      1         1 -10  13  44
# 1              2      26     no     no      b04      1         2  11  11  26
# 2              3      26     no     no      b04      1         3   0   2  20
# 3              4      26     no     no      b04      1         4   3  14  -4
# 4              5      26     no     no      b04      1         5  21  20   9
# ...          ...     ...    ...    ...      ...    ...       ...  ..  ..  ..
# 4645        4646     213    yes     no      b01      1        46  41  16 -16
# 4646        4647     213    yes     no      b01      1        47  31  35  15
# 4647        4648     213    yes     no      b01      1        48  23  39  17
# 4648        4649     213    yes     no      b01      1        49   6  18   5
# 4649        4650     213    yes     no      b01      1        50  10  10  -9
#
#       b4  resp  advantageous  switch
# ...

# %%
my_cols = ['stable','stress']
df[my_cols]
# Out:
#      stable stress
# 0        no     no
# 1        no     no
# 2        no     no
# 3        no     no
# 4        no     no
# ...     ...    ...
# 4795    yes     no
# 4796    yes     no
# 4797    yes     no
# 4798    yes     no
# 4799    yes     no
#
# [4800 rows x 2 columns]

# %%
df.loc[45]['stable']
# Out:
# 'no'

# %%
df.run_id[26]
y = df.groupby('run_id')
y.count()
# Out:
#         Unnamed: 0  stress  stable  block_no  block  trial_no   b1   b2   b3  \
# run_id
# 3              200     200     200       200    200       200  200  200  200
# 8              200     200     200       200    200       200  200  200  200
# 9              200     200     200       200    200       200  200  200  200
# 17             200     200     200       200    200       200  200  200  200
# 24             200     200     200       200    200       200  200  200  200
# 26             200     200     200       200    200       200  200  200  200
# 28             200     200     200       200    200       200  200  200  200
# 29             200     200     200       200    200       200  200  200  200
# 31             200     200     200       200    200       200  200  200  200
# 32             200     200     200       200    200       200  200  200  200
# 46             200     200     200       200    200       200  200  200  200
# ...

# %%
p1 = df[df['run_id'] == 26]

# %%
p1
# Out:
#      Unnamed: 0  run_id stress stable block_no  block  trial_no  b1  b2  b3  \
# 0             1      26     no     no      b04      1         1 -10  13  44
# 1             2      26     no     no      b04      1         2  11  11  26
# 2             3      26     no     no      b04      1         3   0   2  20
# 3             4      26     no     no      b04      1         4   3  14  -4
# 4             5      26     no     no      b04      1         5  21  20   9
# ..          ...     ...    ...    ...      ...    ...       ...  ..  ..  ..
# 195         196      26    yes    yes      b11      4        46 -25 -19   6
# 196         197      26    yes    yes      b11      4        47 -22  -3  -1
# 197         198      26    yes    yes      b11      4        48 -20 -14  14
# 198         199      26    yes    yes      b11      4        49 -23  -3  -4
# 199         200      26    yes    yes      b11      4        50 -24  -8  -3
#
#      b4  resp  advantageous  switch
# ...

# %%
p1_b1 = p1[p1['switch'] == 1]

# %%
p1_b1.set_index('Unnamed: 0')
# Out:
#             run_id stress stable block_no  block  trial_no  b1  b2  b3  b4  \
# Unnamed: 0
# 3               26     no     no      b04      1         3   0   2  20   0
# 5               26     no     no      b04      1         5  21  20   9 -46
# 7               26     no     no      b04      1         7  40  26   7 -80
# 8               26     no     no      b04      1         8  34  11  14 -80
# 11              26     no     no      b04      1        11   2  31   2 -57
# ...            ...    ...    ...      ...    ...       ...  ..  ..  ..  ..
# 191             26    yes    yes      b11      4        41 -15 -21  -2  13
# 195             26    yes    yes      b11      4        45 -20 -20   4 -14
# 196             26    yes    yes      b11      4        46 -25 -19   6   1
# 197             26    yes    yes      b11      4        47 -22  -3  -1  -1
# 200             26    yes    yes      b11      4        50 -24  -8  -3  12
#
#             resp  advantageous  switch
# Unnamed: 0
# ...

# %%
x = p1_b1.groupby('block')
x.sum()
# Out:
#        Unnamed: 0  run_id  trial_no   b1   b2   b3   b4  resp  advantageous  \
# block
# 1             558     572       558  284  132 -167 -585    42             8
# 2            1235     442       385 -680  504  111   28    39             4
# 3            2136     442       436   71 -406   16 -548    38             7
# 4            4865     728       665 -151 -644  179  -57    61            10
#
#        switch
# block
# 1        22.0
# 2        17.0
# 3        17.0
# 4        28.0

# %%
df['block']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4795    4
# 4796    4
# 4797    4
# 4798    4
# 4799    4
# Name: block, Length: 4800, dtype: int64

# %%
arr = np.array([])

# %%
sum1 = 0
for i in range(1,5):
    {
      print(x.sum().loc[i]['advantageous'])
    }
# Out:
# 8.0
# 4.0
# 7.0
# 10.0

# %%
switch_b1 = x.count().loc[1]['switch']

# %%
x

# %%
x.count()
# Out:
#        Unnamed: 0  run_id  stress  stable  block_no  trial_no  b1  b2  b3  b4  \
# block
# 1              22      22      22      22        22        22  22  22  22  22
# 2              17      17      17      17        17        17  17  17  17  17
# 3              17      17      17      17        17        17  17  17  17  17
# 4              28      28      28      28        28        28  28  28  28  28
#
#        resp  advantageous  switch
# block
# 1        22            22      22
# 2        17            17      17
# 3        17            17      17
# 4        28            28      28

# %%
adv = p1['advantageous'].value_counts()

# %%
adv
# Out:
# 1    105
# 0     95
# Name: advantageous, dtype: int64

# %%
adv_p1 = adv.loc[1]

# %%
proportion_adv = adv_p1/(adv.loc[0] + adv_p1)
print(proportion_adv)
# Out:
# 0.525

# %%
p1
# Out:
#      Unnamed: 0  run_id stress stable block_no  block  trial_no  b1  b2  b3  \
# 0             1      26     no     no      b04      1         1 -10  13  44
# 1             2      26     no     no      b04      1         2  11  11  26
# 2             3      26     no     no      b04      1         3   0   2  20
# 3             4      26     no     no      b04      1         4   3  14  -4
# 4             5      26     no     no      b04      1         5  21  20   9
# ..          ...     ...    ...    ...      ...    ...       ...  ..  ..  ..
# 195         196      26    yes    yes      b11      4        46 -25 -19   6
# 196         197      26    yes    yes      b11      4        47 -22  -3  -1
# 197         198      26    yes    yes      b11      4        48 -20 -14  14
# 198         199      26    yes    yes      b11      4        49 -23  -3  -4
# 199         200      26    yes    yes      b11      4        50 -24  -8  -3
#
#      b4  resp  advantageous  switch
# ...

# %%
total_adv = df['advantageous'].sum()
total_adv
# Out:
# 2373

# %%
df
# Out:
#       Unnamed: 0  run_id stress stable block_no  block  trial_no  b1  b2  b3  \
# 0              1      26     no     no      b04      1         1 -10  13  44
# 1              2      26     no     no      b04      1         2  11  11  26
# 2              3      26     no     no      b04      1         3   0   2  20
# 3              4      26     no     no      b04      1         4   3  14  -4
# 4              5      26     no     no      b04      1         5  21  20   9
# ...          ...     ...    ...    ...      ...    ...       ...  ..  ..  ..
# 4795        4796     213     no    yes      b13      4        46 -15  -3  20
# 4796        4797     213     no    yes      b13      4        47 -23 -10  13
# 4797        4798     213     no    yes      b13      4        48 -15  -2   6
# 4798        4799     213     no    yes      b13      4        49 -18  -8   3
# 4799        4800     213     no    yes      b13      4        50 -13  -1   9
#
#       b4  resp  advantageous  switch
# ...

# %%
a = df.groupby(['run_id','block'])

# %%
total = a.count()
ob = a.sum()

# %%
new.head(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 new.head(50)
#
# NameError: name 'new' is not defined

# %%
ob
# Out:
#               Unnamed: 0  trial_no    b1    b2    b3    b4  resp  \
# run_id block
# 3      1           51275      1275   309   428 -1614  -258   104
#        2           53775      1275   104   917  1065  1736   139
#        3           56275      1275  -702   659  -583   533   132
#        4           58775      1275    31 -1538 -1091   278   101
# 8      1          171275      1275   309 -1614  -258   428   129
# ...                  ...       ...   ...   ...   ...   ...   ...
# 213    4          238775      1275 -1363   -26  -311  -221   135
# 215    1          221275      1275 -1538 -1091    31   278   145
#        2          223775      1275   -26 -1363  -221  -311   131
#        3          226275      1275  -258 -1614   428   309   168
#        4          228775      1275  1065  1736   917   104   122
#
#               advantageous  switch
# run_id block
# 3      1                29    20.0
#        2                22    33.0
#        3                27    26.0
# ...

# %%
arr = np.array([])
arr1 = np.array([])

# %%
ob.loc[3]['b1'].loc[1]
# Out:
# 309

# %%
for i in range(1,5):
    arr1 = np.append(arr1,ob.loc[3]['switch'].loc[i])

# %%
arr1
# Out:
# array([20., 33., 26., 33.])

# %%
runid = np.append(arr,df['run_id'])

# %%
runid_new = np.unique(runid)
runid_new
# Out:
# array([  3.,   8.,   9.,  17.,  24.,  26.,  28.,  29.,  31.,  32.,  46.,
#         49.,  50.,  53.,  54.,  57.,  61.,  66.,  71.,  73.,  74.,  76.,
#        213., 215.])

# %%
arr2 = np.array([])
for i in runid_new:
        arr2 = np.append(arr2,ob.loc[i]['switch'])
arr2
# Out:
# array([20., 33., 26., 33., 19.,  9., 18., 10., 20., 10., 11., 10., 24.,
#         5.,  3., 10., 25., 18., 26.,  9., 22., 17., 17., 28., 22.,  8.,
#        20., 14., 20., 23., 27., 27., 36., 11.,  8., 15., 32., 23., 28.,
#        31., 17., 24., 21., 18., 23., 24., 20.,  4., 26., 32., 26., 14.,
#        19.,  4., 15., 11., 22., 11., 15., 16., 20., 19., 21., 10., 36.,
#        39., 37., 33., 27., 14., 12., 11., 21., 21., 18., 23., 23., 14.,
#        10., 11., 16.,  1., 11., 15., 47., 46., 49., 45., 17., 16., 18.,
#        21., 27., 16., 10., 13.])

# %%
ob['No_of_switches'] = arr2
ob
# Out:
#               Unnamed: 0  trial_no    b1    b2    b3    b4  resp  \
# run_id block
# 3      1           51275      1275   309   428 -1614  -258   104
#        2           53775      1275   104   917  1065  1736   139
#        3           56275      1275  -702   659  -583   533   132
#        4           58775      1275    31 -1538 -1091   278   101
# 8      1          171275      1275   309 -1614  -258   428   129
# ...                  ...       ...   ...   ...   ...   ...   ...
# 213    4          238775      1275 -1363   -26  -311  -221   135
# 215    1          221275      1275 -1538 -1091    31   278   145
#        2          223775      1275   -26 -1363  -221  -311   131
#        3          226275      1275  -258 -1614   428   309   168
#        4          228775      1275  1065  1736   917   104   122
#
#               advantageous  switch  No_of_switches
# run_id block
# 3      1                29    20.0            20.0
#        2                22    33.0            33.0
# ...

# %%
arr3 = np.array([])
def divide(x):
    return x/50

for i in runid_new:
        arr3 = np.append(arr3,ob.loc[i]['advantageous'].apply(divide))
arr3
# Out:
# array([0.58, 0.44, 0.54, 0.54, 0.44, 0.5 , 0.5 , 0.56, 0.66, 0.54, 0.44,
#        0.38, 0.48, 0.42, 0.46, 0.3 , 0.6 , 0.66, 0.46, 0.24, 0.42, 0.5 ,
#        0.62, 0.56, 0.38, 0.6 , 0.56, 0.62, 0.66, 0.64, 0.3 , 0.48, 0.4 ,
#        0.48, 0.58, 0.72, 0.4 , 0.34, 0.24, 0.42, 0.5 , 0.56, 0.62, 0.62,
#        0.58, 0.6 , 0.5 , 0.46, 0.6 , 0.48, 0.42, 0.36, 0.32, 0.26, 0.72,
#        0.38, 0.6 , 0.56, 0.56, 0.42, 0.44, 0.48, 0.58, 0.34, 0.32, 0.26,
#        0.38, 0.56, 0.38, 0.7 , 0.66, 0.64, 0.54, 0.5 , 0.5 , 0.62, 0.42,
#        0.66, 0.58, 0.64, 0.44, 0.24, 0.58, 0.72, 0.26, 0.26, 0.3 , 0.22,
#        0.46, 0.62, 0.72, 0.6 , 0.58, 0.56, 0.6 , 0.32])

# %%
ob['prop_of_advchoices'] = arr3

# %%
ob.head(30)
# Out:
#               Unnamed: 0  trial_no    b1    b2    b3    b4  resp  \
# run_id block
# 3      1           51275      1275   309   428 -1614  -258   104
#        2           53775      1275   104   917  1065  1736   139
#        3           56275      1275  -702   659  -583   533   132
#        4           58775      1275    31 -1538 -1091   278   101
# 8      1          171275      1275   309 -1614  -258   428   129
#        2          173775      1275    52   385  1300 -1143   127
#        3          176275      1275  -352   385   -11 -1122    99
#        4          178775      1275  -702   659   533  -583   126
# 9      1          211275      1275 -1363   -26  -311  -221   144
#        2          213775      1275   533  -583  -702   659   122
#        3          216275      1275  1300 -1143    52   385   114
#        4          218775      1275  1736   104  1065   917    84
# 17     1           21275      1275 -1122   385  -352   -11   141
# ...

# %%
scores = []

# %%
df
# Out:
#       Unnamed: 0  run_id stress stable block_no  block  trial_no  b1  b2  b3  \
# 0              1      26     no     no      b04      1         1 -10  13  44
# 1              2      26     no     no      b04      1         2  11  11  26
# 2              3      26     no     no      b04      1         3   0   2  20
# 3              4      26     no     no      b04      1         4   3  14  -4
# 4              5      26     no     no      b04      1         5  21  20   9
# ...          ...     ...    ...    ...      ...    ...       ...  ..  ..  ..
# 4795        4796     213     no    yes      b13      4        46 -15  -3  20
# 4796        4797     213     no    yes      b13      4        47 -23 -10  13
# 4797        4798     213     no    yes      b13      4        48 -15  -2   6
# 4798        4799     213     no    yes      b13      4        49 -18  -8   3
# 4799        4800     213     no    yes      b13      4        50 -13  -1   9
#
#       b4  resp  advantageous  switch  choice
# ...

# %%
df['proportion_advchoices'] = np.nan
df['switches_in_block'] = np.nan
df
# Out:
#       Unnamed: 0  run_id stress stable block_no  block  trial_no  b1  b2  b3  \
# 0              1      26     no     no      b04      1         1 -10  13  44
# 1              2      26     no     no      b04      1         2  11  11  26
# 2              3      26     no     no      b04      1         3   0   2  20
# 3              4      26     no     no      b04      1         4   3  14  -4
# 4              5      26     no     no      b04      1         5  21  20   9
# ...          ...     ...    ...    ...      ...    ...       ...  ..  ..  ..
# 4795        4796     213     no    yes      b13      4        46 -15  -3  20
# 4796        4797     213     no    yes      b13      4        47 -23 -10  13
# 4797        4798     213     no    yes      b13      4        48 -15  -2   6
# 4798        4799     213     no    yes      b13      4        49 -18  -8   3
# 4799        4800     213     no    yes      b13      4        50 -13  -1   9
#
# ...

# %%
arr3 = np.array([])
def divide(x):
    return x/50

for i in runid_new:
    for j in range(1,5):
        df.loc[(df.run_id == i)& (df.block == j),['proportion_advchoices']] = ob.loc[i]['advantageous'].apply(divide).loc[j]
        df.loc[(df.run_id == i)& (df.block == j),['switches_in_block']] = ob.loc[i]['switch'].loc[j]

# %%
ch = np.ones(4800)
df['choices'] = ch

# %%
a = [1,2,3]
b = np.ones(3)
df1 = pd.DataFrame()
df1['first'] = a
df1['second'] = b

# %%
df1
# Out:
#    first  second
# 0      1     1.0
# 1      2     1.0
# 2      3     1.0

# %%
type(ch)
# Out:
# numpy.ndarray

# %%
len(ch)
# Out:
# 4800

# %%
df
# Out:
#       Unnamed: 0  run_id stress stable block_no  block  trial_no  b1  b2  b3  \
# 0              1      26     no     no      b04      1         1 -10  13  44
# 1              2      26     no     no      b04      1         2  11  11  26
# 2              3      26     no     no      b04      1         3   0   2  20
# 3              4      26     no     no      b04      1         4   3  14  -4
# 4              5      26     no     no      b04      1         5  21  20   9
# ...          ...     ...    ...    ...      ...    ...       ...  ..  ..  ..
# 4795        4796     213     no    yes      b13      4        46 -15  -3  20
# 4796        4797     213     no    yes      b13      4        47 -23 -10  13
# 4797        4798     213     no    yes      b13      4        48 -15  -2   6
# 4798        4799     213     no    yes      b13      4        49 -18  -8   3
# 4799        4800     213     no    yes      b13      4        50 -13  -1   9
#
# ...

# %%
len(df)
# Out:
# 4800

# %%
df['choice'] = np.nan
df
# Out:
#       Unnamed: 0  run_id stress stable block_no  block  trial_no  b1  b2  b3  \
# 0              1      26     no     no      b04      1         1 -10  13  44
# 1              2      26     no     no      b04      1         2  11  11  26
# 2              3      26     no     no      b04      1         3   0   2  20
# 3              4      26     no     no      b04      1         4   3  14  -4
# 4              5      26     no     no      b04      1         5  21  20   9
# ...          ...     ...    ...    ...      ...    ...       ...  ..  ..  ..
# 4795        4796     213     no    yes      b13      4        46 -15  -3  20
# 4796        4797     213     no    yes      b13      4        47 -23 -10  13
# 4797        4798     213     no    yes      b13      4        48 -15  -2   6
# 4798        4799     213     no    yes      b13      4        49 -18  -8   3
# 4799        4800     213     no    yes      b13      4        50 -13  -1   9
#
# ...

# %%
for i in range(0,4800):
    if(df['resp'].loc[i] != 0):
        resp_no = df['resp'].loc[i]
        b = 'b'+ str(resp_no)
        df.loc[i, ['choice']] = df.loc[i][b]
df
# Out:
#       Unnamed: 0  run_id stress stable block_no  block  trial_no  b1  b2  b3  \
# 0              1      26     no     no      b04      1         1 -10  13  44
# 1              2      26     no     no      b04      1         2  11  11  26
# 2              3      26     no     no      b04      1         3   0   2  20
# 3              4      26     no     no      b04      1         4   3  14  -4
# 4              5      26     no     no      b04      1         5  21  20   9
# ...          ...     ...    ...    ...      ...    ...       ...  ..  ..  ..
# 4795        4796     213     no    yes      b13      4        46 -15  -3  20
# 4796        4797     213     no    yes      b13      4        47 -23 -10  13
# 4797        4798     213     no    yes      b13      4        48 -15  -2   6
# 4798        4799     213     no    yes      b13      4        49 -18  -8   3
# 4799        4800     213     no    yes      b13      4        50 -13  -1   9
#
# ...

# %%
df.loc[df.choice == ''] = 0
df[df['choice'] == '']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, run_id, stress, stable, block_no, block, trial_no, b1, b2, b3, b4, resp, advantageous, switch, choice, proportion_advchoices, switches_in_block, choices]
# Index: []

# %%
df
# Out:
#       Unnamed: 0  run_id stress stable block_no  block  trial_no  b1  b2  b3  \
# 0              1      26     no     no      b04      1         1 -10  13  44
# 1              2      26     no     no      b04      1         2  11  11  26
# 2              3      26     no     no      b04      1         3   0   2  20
# 3              4      26     no     no      b04      1         4   3  14  -4
# 4              5      26     no     no      b04      1         5  21  20   9
# ...          ...     ...    ...    ...      ...    ...       ...  ..  ..  ..
# 4795        4796     213     no    yes      b13      4        46 -15  -3  20
# 4796        4797     213     no    yes      b13      4        47 -23 -10  13
# 4797        4798     213     no    yes      b13      4        48 -15  -2   6
# 4798        4799     213     no    yes      b13      4        49 -18  -8   3
# 4799        4800     213     no    yes      b13      4        50 -13  -1   9
#
# ...

# %%
m = df.groupby(['run_id', 'block'])

# %%
x = m.mean()

# %%
x
# Out:
#               Unnamed: 0  trial_no     b1     b2     b3     b4  resp  \
# run_id block
# 3      1          1025.5      25.5   6.18   8.56 -32.28  -5.16  2.08
#        2          1075.5      25.5   2.08  18.34  21.30  34.72  2.78
#        3          1125.5      25.5 -14.04  13.18 -11.66  10.66  2.64
#        4          1175.5      25.5   0.62 -30.76 -21.82   5.56  2.02
# 8      1          3425.5      25.5   6.18 -32.28  -5.16   8.56  2.58
# ...                  ...       ...    ...    ...    ...    ...   ...
# 213    4          4775.5      25.5 -27.26  -0.52  -6.22  -4.42  2.70
# 215    1          4425.5      25.5 -30.76 -21.82   0.62   5.56  2.90
#        2          4475.5      25.5  -0.52 -27.26  -4.42  -6.22  2.62
#        3          4525.5      25.5  -5.16 -32.28   8.56   6.18  3.36
#        4          4575.5      25.5  21.30  34.72  18.34   2.08  2.44
#
#               advantageous    switch     choice  proportion_advchoices  \
# run_id block
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
score = pd.read_csv('MAB.csv')

# %%
score
# Out:
#                                              StartDate  \
# 0                                           Start Date
# 1    {"ImportId":"startDate","timeZone":"America/De...
# 2                                  2022-05-16 22:55:50
# 3                                  2022-05-16 23:03:51
# 4                                  2022-05-18 06:45:34
# ..                                                 ...
# 144                                2022-06-15 11:02:16
# 145                                2022-06-15 12:54:04
# 146                                2022-06-15 13:20:49
# 147                                2022-06-16 07:02:21
# 148                                2022-06-20 02:05:45
#
#                                                EndDate                 Status  \
# 0                                             End Date          Response Type
# 1    {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# ...

# %%
x
# Out:
#               Unnamed: 0  trial_no     b1     b2     b3     b4  resp  \
# run_id block
# 3      1          1025.5      25.5   6.18   8.56 -32.28  -5.16  2.08
#        2          1075.5      25.5   2.08  18.34  21.30  34.72  2.78
#        3          1125.5      25.5 -14.04  13.18 -11.66  10.66  2.64
#        4          1175.5      25.5   0.62 -30.76 -21.82   5.56  2.02
# 8      1          3425.5      25.5   6.18 -32.28  -5.16   8.56  2.58
# ...                  ...       ...    ...    ...    ...    ...   ...
# 213    4          4775.5      25.5 -27.26  -0.52  -6.22  -4.42  2.70
# 215    1          4425.5      25.5 -30.76 -21.82   0.62   5.56  2.90
#        2          4475.5      25.5  -0.52 -27.26  -4.42  -6.22  2.62
#        3          4525.5      25.5  -5.16 -32.28   8.56   6.18  3.36
#        4          4575.5      25.5  21.30  34.72  18.34   2.08  2.44
#
#               advantageous    switch     choice  proportion_advchoices  \
# run_id block
# ...

# %%
sns.countplot(y = 'switches_in_block', data = x.loc[3])
# Out:
# <AxesSubplot:xlabel='count', ylabel='switches_in_block'>

# %%
 m = x.loc[3]
m
# Out:
#        Unnamed: 0  trial_no     b1     b2     b3     b4  resp  advantageous  \
# block
# 1          1025.5      25.5   6.18   8.56 -32.28  -5.16  2.08          0.58
# 2          1075.5      25.5   2.08  18.34  21.30  34.72  2.78          0.44
# 3          1125.5      25.5 -14.04  13.18 -11.66  10.66  2.64          0.54
# 4          1175.5      25.5   0.62 -30.76 -21.82   5.56  2.02          0.54
#
#          switch     choice  proportion_advchoices  switches_in_block  choices
# block
# 1      0.408163  24.918367                   0.58               20.0      1.0
# 2      0.673469  36.020408                   0.44               33.0      1.0
# 3      0.530612  11.500000                   0.54               26.0      1.0
# 4      0.673469   1.040816                   0.54               33.0      1.0

# %%
m.plot.bar(y = 'switches_in_block', rot = 0)
# Out:
# <AxesSubplot:xlabel='block'>

# %%
m.plot.bar(y = 'proportion_advchoices', rot = 0)
# Out:
# <AxesSubplot:xlabel='block'>

# %%
x
# Out:
#               Unnamed: 0  trial_no     b1     b2     b3     b4  resp  \
# run_id block
# 3      1          1025.5      25.5   6.18   8.56 -32.28  -5.16  2.08
#        2          1075.5      25.5   2.08  18.34  21.30  34.72  2.78
#        3          1125.5      25.5 -14.04  13.18 -11.66  10.66  2.64
#        4          1175.5      25.5   0.62 -30.76 -21.82   5.56  2.02
# 8      1          3425.5      25.5   6.18 -32.28  -5.16   8.56  2.58
# ...                  ...       ...    ...    ...    ...    ...   ...
# 213    4          4775.5      25.5 -27.26  -0.52  -6.22  -4.42  2.70
# 215    1          4425.5      25.5 -30.76 -21.82   0.62   5.56  2.90
#        2          4475.5      25.5  -0.52 -27.26  -4.42  -6.22  2.62
#        3          4525.5      25.5  -5.16 -32.28   8.56   6.18  3.36
#        4          4575.5      25.5  21.30  34.72  18.34   2.08  2.44
#
#               advantageous    switch     choice  proportion_advchoices  \
# run_id block
# ...

# %%
axes = plots.plot.bar(
    rot=0, subplots=True, color={"switches_in_block": "red", "proportion_advchoices": "green"}
)
axes[1].legend(loc=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [115], in <cell line: 1>()
# ----> 1 axes = plots.plot.bar(
#       2     rot=0, subplots=True, color={"switches_in_block": "red", "proportion_advchoices": "green"}
#       3 )
#       4 axes[1].legend(loc=2)
#
# NameError: name 'plots' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import math
figure(num=None, figsize=(10, 4))
font = {'family' : 'Times New Roman',
        'weight' : 'bold',
        'size'   : 15}

plt.rc('font', **font)

# Defines values for the first plot
x1 = m.index
y1 = m['switches_in_block']

# Defines values for the second plot
x2 = m.index
y2 = m['proportion_advchoices']

# Draw first subplot using plt.subplot
plt.subplot(1, 2, 1)
plt.bar(x1,y1, color='lightblue', width = 0.8)
# plt.yscale('log')            # Defines log scale
plt.xlabel('Block')
plt.ylabel('Number of Switches')

# Draw second subplot using plt.subplot
plt.subplot(1, 2, 2)
plt.bar(x2,y2, color = 'deepskyblue')
#plt.yscale('log')            # Defines log scale
plt.xlabel('block')
plt.ylabel('Proportion of Advantageous Choices')

plt.show()

# %%
ob
# Out:
#               Unnamed: 0  trial_no    b1    b2    b3    b4  resp  \
# run_id block
# 3      1           51275      1275   309   428 -1614  -258   104
#        2           53775      1275   104   917  1065  1736   139
#        3           56275      1275  -702   659  -583   533   132
#        4           58775      1275    31 -1538 -1091   278   101
# 8      1          171275      1275   309 -1614  -258   428   129
# ...                  ...       ...   ...   ...   ...   ...   ...
# 213    4          238775      1275 -1363   -26  -311  -221   135
# 215    1          221275      1275 -1538 -1091    31   278   145
#        2          223775      1275   -26 -1363  -221  -311   131
#        3          226275      1275  -258 -1614   428   309   168
#        4          228775      1275  1065  1736   917   104   122
#
#               advantageous  switch  No_of_switches  prop_of_advchoices
# run_id block
# 3      1                29    20.0            20.0                0.58
# ...

# %%
new = df.groupby('run_id')

# %%
new

# %%
s = new.sum()
s
# Out:
#         Unnamed: 0  block  trial_no    b1    b2    b3    b4  resp  \
# run_id
# 3           220100    500      5100  -258   466 -2223  2289   476
# 8           700100    500      5100  -693  -185  1564 -2420   481
# 9           860100    500      5100  2206 -1648   104  1740   464
# 17          100100    500      5100 -2921   308  1547 -1070   440
# 24           60100    500      5100  -968   113 -2087  -458   420
# 26           20100    500      5100  -789  -604   210 -2778   451
# 28          140100    500      5100 -2530  -848   271  3099   609
# 29          180100    500      5100 -3351   409  -295 -2570   499
# 31          260100    500      5100 -2893  -511 -2555  -570   513
# 32          300100    500      5100 -1750  2233 -1406  2743   591
# 46          340100    500      5100 -3902 -1468 -2131  -856   530
# 49          380100    500      5100  -906  -777 -1199  -917   487
# 50          460100    500      5100 -2379 -1492  1858 -3162   518
# ...

# %%
s.hist(column = 'switch', bins = 15)
# Out:
# array([[<AxesSubplot:title={'center':'switch'}>]], dtype=object)

# %%
s.hist(column = 'advantageous', bins = 20)
# Out:
# array([[<AxesSubplot:title={'center':'advantageous'}>]], dtype=object)

# %%
df[df.run_id == 3][df.block == 3]
# Out:
# C:\Users\Saloni\AppData\Local\Temp\ipykernel_20168\3152368568.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.run_id == 3][df.block == 3]
#       Unnamed: 0  run_id stress stable block_no  block  trial_no  b1  b2  b3  \
# 1100        1101       3     no    yes      b10      3         1 -36  30 -11
# 1101        1102       3     no    yes      b10      3         2 -30  35 -12
# 1102        1103       3     no    yes      b10      3         3 -45  42  -4
# 1103        1104       3     no    yes      b10      3         4 -29  36 -12
# 1104        1105       3     no    yes      b10      3         5 -35  33 -11
# 1105        1106       3     no    yes      b10      3         6 -36  40 -12
# 1106        1107       3     no    yes      b10      3         7 -38  36  -7
# 1107        1108       3     no    yes      b10      3         8 -39  39   2
# 1108        1109       3     no    yes      b10      3         9 -38  47   0
# ...

# %%
s['switch'].plot(kind='hist', title='No. of switches', xlabel='No. of switches', ylabel='', xticks = np.arange(0,200,20))
# Out:
# <AxesSubplot:title={'center':'No. of switches'}, ylabel='Frequency'>

# %%
s['advantageous'].plot(kind='hist', title='No.of advantageous choices', xlabel='No. of swicthes', ylabel='h')
# Out:
# <AxesSubplot:title={'center':'No.of advantageous choices'}, ylabel='Frequency'>

# %%
df['block_no'].value_counts()
# Out:
# b04    700
# b11    700
# b12    500
# b02    500
# b10    500
# b03    450
# b01    400
# b14    350
# b13    350
# b00    350
# Name: block_no, dtype: int64

# %%
df
# Out:
#       Unnamed: 0  run_id stress stable block_no  block  trial_no  b1  b2  b3  \
# 0              1      26     no     no      b04      1         1 -10  13  44
# 1              2      26     no     no      b04      1         2  11  11  26
# 2              3      26     no     no      b04      1         3   0   2  20
# 3              4      26     no     no      b04      1         4   3  14  -4
# 4              5      26     no     no      b04      1         5  21  20   9
# ...          ...     ...    ...    ...      ...    ...       ...  ..  ..  ..
# 4795        4796     213     no    yes      b13      4        46 -15  -3  20
# 4796        4797     213     no    yes      b13      4        47 -23 -10  13
# 4797        4798     213     no    yes      b13      4        48 -15  -2   6
# 4798        4799     213     no    yes      b13      4        49 -18  -8   3
# 4799        4800     213     no    yes      b13      4        50 -13  -1   9
#
# ...

# %%
score = pd.read_csv('MAB_0.csv')
score
# Out:
#                     Status                 IPAddress                 Progress  \
# 0            Response Type                IP Address                 Progress
# 1    {"ImportId":"status"}  {"ImportId":"ipAddress"}  {"ImportId":"progress"}
# 2               IP Address              202.3.77.166                      100
# 3               IP Address              202.3.77.166                      100
# 4               IP Address              103.172.8.13                      100
# ..                     ...                       ...                      ...
# 144             IP Address              202.3.77.207                       50
# 145             IP Address             14.139.38.110                       28
# 146             IP Address            106.206.57.106                       11
# 147             IP Address             14.139.38.176                       94
# 148             IP Address             14.139.38.155                       94
#
# ...

# %%
a = [26,27,28,30,31]
final_score = []

# %%
greetings = "Hello World"

print(greetings)
# Hello World
# Out:
# Hello World

# %%
for i in range(2, 149):
    s = 0
    for j in range(1,46):
        x = "% s" % j
        ques = 'Prompt_' + x
        if j in a:
            if(score.loc[i][ques] == 'No'):
                s = s+1
        else :
            if(score.loc[i][ques] == 'Yes'):
                s = s+1
    final_score = np.append(final_score, s)

# %%
final_score
# Out:
# array([40., 40., 15., 15., 40., 35., 31., 34., 22., 27., 25., 21., 23.,
#        18., 28., 19., 24., 23., 33., 24., 30., 27., 25., 19., 24., 19.,
#        28., 28., 16., 18., 12., 22., 23., 24., 11., 21., 16., 25., 15.,
#        25., 17., 28., 25., 27., 18., 15., 21., 25., 21., 29.,  7., 19.,
#        11., 21., 24., 27., 30., 26., 10., 13., 25., 22., 24., 13., 39.,
#        22.,  0., 18.,  0.,  0.,  0.,  0., 31., 18., 22.,  0., 25., 19.,
#        21., 26., 25.,  0., 27.,  8., 26., 14., 17., 31., 14., 29., 31.,
#        15., 30.,  0., 23., 23., 24.,  0.,  0., 36., 20.,  0., 26., 21.,
#         0., 25.,  0., 21., 32., 24., 31., 22., 20., 29., 13., 26., 22.,
#        31., 21., 22., 14., 24., 16., 15., 31., 25., 26., 17., 26., 20.,
#        22., 22., 17.,  9., 28., 24., 38., 20., 17., 24.,  0., 26.,  0.,
#        30.,  0., 39., 21.])

# %%
x = [0, 0]
final_score = np.append(x,final_score)

# %%
final_score.size
# Out:
# 149

# %%
score['Score'] = final_score

# %%
score
# Out:
#                     Status                 IPAddress                 Progress  \
# 0            Response Type                IP Address                 Progress
# 1    {"ImportId":"status"}  {"ImportId":"ipAddress"}  {"ImportId":"progress"}
# 2               IP Address              202.3.77.166                      100
# 3               IP Address              202.3.77.166                      100
# 4               IP Address              103.172.8.13                      100
# ..                     ...                       ...                      ...
# 144             IP Address              202.3.77.207                       50
# 145             IP Address             14.139.38.110                       28
# 146             IP Address            106.206.57.106                       11
# 147             IP Address             14.139.38.176                       94
# 148             IP Address             14.139.38.155                       94
#
# ...

# %%
plt.hist(score['Score'], bins = 50)
# Out:
# (array([18.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.,  0.,  1.,  1.,  1.,
#          2.,  0.,  1.,  3.,  3.,  6.,  0.,  3.,  5.,  5.,  5.,  0.,  4.,
#         10., 10.,  5.,  0., 11., 11.,  8.,  5.,  0.,  5.,  3.,  4.,  7.,
#          0.,  1.,  1.,  1.,  1.,  0.,  1.,  0.,  1.,  2.,  3.]),
#  array([ 0. ,  0.8,  1.6,  2.4,  3.2,  4. ,  4.8,  5.6,  6.4,  7.2,  8. ,
#          8.8,  9.6, 10.4, 11.2, 12. , 12.8, 13.6, 14.4, 15.2, 16. , 16.8,
#         17.6, 18.4, 19.2, 20. , 20.8, 21.6, 22.4, 23.2, 24. , 24.8, 25.6,
#         26.4, 27.2, 28. , 28.8, 29.6, 30.4, 31.2, 32. , 32.8, 33.6, 34.4,
#         35.2, 36. , 36.8, 37.6, 38.4, 39.2, 40. ]),
#  <BarContainer object of 50 artists>)

# %%
y = pd.read_csv('pilot2_raw.csv')

# %%
y
# Out:
#        run_id  condition success timeout failed_images failed_audio  \
# 0          26          1    TRUE   FALSE            []           []
# 1          26          1       "       "             "            "
# 2          26          1       "       "             "            "
# 3          26          1       "       "             "            "
# 4          26          1       "       "             "            "
# ...       ...        ...     ...     ...           ...          ...
# 15379     213          1       "       "             "            "
# 15380     213          1       "       "             "            "
# 15381     213          1       "       "             "            "
# 15382     213          1       "       "             "            "
# 15383     213          1       "       "             "            "
#
#       failed_video              trial_type  trial_index  time_elapsed  ...  \
# ...

# %%
y = y.loc[y['r ponse'].notnull()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Response'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
m = y[y['response'].notnull()]

# %%
m[(m['response'] != '-1') & (m['response'] != '0')]['response'].head(100)
# Out:
# 0                                                       "
# 2       {"age":"21","sex":"male","hand":"right","Q3":"...
# 3                                        {"ID":"1763189"}
# 8                                                       1
# 9                                                      []
#                               ...
# 3497                                                   39
# 3528                                                   39
# 3530                                                   []
# 3655                                                    5
# 3686                                                    5
# Name: response, Length: 100, dtype: object

# %%
pilot = pd.read_csv('pilot_main_p1.csv', usecols =['run_id','response'] )

# %%
pilot
# Out:
#        run_id                                           response
# 0         116                                                NaN
# 1         116                                                  0
# 2         116  {"age":"24","sex":"Male","hand":"right","rno":...
# 3         116                                   {"ID":"9220570"}
# 4         116                                                  0
# ...       ...                                                ...
# 53083      97                                                  0
# 53084      97                                                 -1
# 53085      97                                                NaN
# 53086      97                                                 44
# 53087      97                                                NaN
#
# [53088 rows x 2 columns]

# %%
pilot_1 = pilot.dropna()
pilot_1
# Out:
#        run_id                                           response
# 1         116                                                  0
# 2         116  {"age":"24","sex":"Male","hand":"right","rno":...
# 3         116                                   {"ID":"9220570"}
# 4         116                                                  0
# 5         116                                                  0
# ...       ...                                                ...
# 53080      97                                                  0
# 53081      97                                                 -1
# 53083      97                                                  0
# 53084      97                                                 -1
# 53086      97                                                 44
#
# [37051 rows x 2 columns]

# %%
x = pilot.groupby('run_id')

# %%
y = x.sum()
y
# Out:
#                                                  response
# run_id
# 44      0{"age":"22","sex":"male","hand":"right","rno"...
# 49      0{"age":"24","sex":"male","hand":"right","rno"...
# 51      0{"age":"20","sex":"female","hand":"right","rn...
# 66      0{"age":"22","sex":"male","hand":"left","rno":...
# 70      0{"age":"22","sex":"male","hand":"left","rno":...
# ...                                                   ...
# 306     0{"age":"26","sex":"Female","hand":"right","rn...
# 310     0{"age":"20","sex":"female","hand":"right","rn...
# 311     0{"age":"27","sex":"male","hand":"right","rno"...
# 312     0{"age":"20","sex":"male","hand":"right","rno"...
# 313     0{"age":"19","sex":"female","hand":"right","rn...
#
# [79 rows x 1 columns]

# %%
y.loc[312]
# Out:
# response    0{"age":"20","sex":"male","hand":"right","rno"...
# Name: 312, dtype: object

# %%
def present(string):
    if "ID" in string:
        return True
    else:
        return False

# %%
def num(string):
    r = "".join([ele for ele in string if ele.isdigit()]) 
    return r

# %%
ID = pilot_1[pilot_1['response'].apply(present) == True]
ID
# Out:
#        run_id          response
# 3         116  {"ID":"9220570"}
# 675       106  {"ID":"1312031"}
# 1347      104  {"ID":"5537458"}
# 2019      112  {"ID":"4680581"}
# 2691      125  {"ID":"5745208"}
# ...       ...               ...
# 49731      78  {"ID":"4071095"}
# 50403      81  {"ID":"9958587"}
# 51075      83  {"ID":"8747178"}
# 51747      90  {"ID":"6736035"}
# 52419      97  {"ID":"1377226"}
#
# [79 rows x 2 columns]

# %%
ID['Random ID'] = ID['response'].apply(num)
ID
# Out:
# C:\Users\Saloni\AppData\Local\Temp\ipykernel_20168\2870315505.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ID['Random ID'] = ID['response'].apply(num)
#        run_id          response Random_ID Random ID
# 3         116  {"ID":"9220570"}   9220570   9220570
# 675       106  {"ID":"1312031"}   1312031   1312031
# 1347      104  {"ID":"5537458"}   5537458   5537458
# 2019      112  {"ID":"4680581"}   4680581   4680581
# 2691      125  {"ID":"5745208"}   5745208   5745208
# ...       ...               ...       ...       ...
# 49731      78  {"ID":"4071095"}   4071095   4071095
# 50403      81  {"ID":"9958587"}   9958587   9958587
# 51075      83  {"ID":"8747178"}   8747178   8747178
# ...

# %%
ID_1 = ID
ID_1 = ID_1.drop('Random_ID', axis = 1)
ID_1
# Out:
#        run_id          response Random ID
# 3         116  {"ID":"9220570"}   9220570
# 675       106  {"ID":"1312031"}   1312031
# 1347      104  {"ID":"5537458"}   5537458
# 2019      112  {"ID":"4680581"}   4680581
# 2691      125  {"ID":"5745208"}   5745208
# ...       ...               ...       ...
# 49731      78  {"ID":"4071095"}   4071095
# 50403      81  {"ID":"9958587"}   9958587
# 51075      83  {"ID":"8747178"}   8747178
# 51747      90  {"ID":"6736035"}   6736035
# 52419      97  {"ID":"1377226"}   1377226
#
# [79 rows x 3 columns]

# %%
score
# Out:
#                     Status                 IPAddress                 Progress  \
# 0            Response Type                IP Address                 Progress
# 1    {"ImportId":"status"}  {"ImportId":"ipAddress"}  {"ImportId":"progress"}
# 2               IP Address              202.3.77.166                      100
# 3               IP Address              202.3.77.166                      100
# 4               IP Address              103.172.8.13                      100
# ..                     ...                       ...                      ...
# 144             IP Address              202.3.77.207                       50
# 145             IP Address             14.139.38.110                       28
# 146             IP Address            106.206.57.106                       11
# 147             IP Address             14.139.38.176                       94
# 148             IP Address             14.139.38.155                       94
#
# ...

# %%
score_1 = score

# %%
final = pd.merge(score_1,ID_1)

# %%
final
# Out:
#         Status        IPAddress Progress Duration (in seconds) Finished  \
# 0   IP Address     183.83.47.69      100                   348     TRUE
# 1   IP Address    14.139.38.139      100                  1370     TRUE
# 2   IP Address     49.36.95.192      100                  1517     TRUE
# 3   IP Address  122.180.162.180      100                  1732     TRUE
# 4   IP Address  103.105.226.164      100                  1103     TRUE
# ..         ...              ...      ...                   ...      ...
# 69  IP Address   103.48.197.215       94                 16719    FALSE
# 70  IP Address    14.139.38.109       94                506578    FALSE
# 71  IP Address    14.139.38.131       94                  6493    FALSE
# 72  IP Address    14.139.38.108       94                 12488    FALSE
# 73  IP Address    14.139.38.174       94                  2704    FALSE
#
#         RecordedDate         ResponseId RecipientLastName Prompt_1 Prompt_2  \
# ...

# %%
final_1 = final[['run_id','Score']]

# %%
final_1
# Out:
#     run_id  Score
# 0       83   31.0
# 1       49   34.0
# 2       51   22.0
# 3       78   27.0
# 4       97   25.0
# ..     ...    ...
# 69     244   20.0
# 70     283   26.0
# 71     287   21.0
# 72     284   25.0
# 73     295   32.0
#
# [74 rows x 2 columns]

# %%
s
# Out:
#         Unnamed: 0  block  trial_no    b1    b2    b3    b4  resp  \
# run_id
# 3           220100    500      5100  -258   466 -2223  2289   476
# 8           700100    500      5100  -693  -185  1564 -2420   481
# 9           860100    500      5100  2206 -1648   104  1740   464
# 17          100100    500      5100 -2921   308  1547 -1070   440
# 24           60100    500      5100  -968   113 -2087  -458   420
# 26           20100    500      5100  -789  -604   210 -2778   451
# 28          140100    500      5100 -2530  -848   271  3099   609
# 29          180100    500      5100 -3351   409  -295 -2570   499
# 31          260100    500      5100 -2893  -511 -2555  -570   513
# 32          300100    500      5100 -1750  2233 -1406  2743   591
# 46          340100    500      5100 -3902 -1468 -2131  -856   530
# 49          380100    500      5100  -906  -777 -1199  -917   487
# 50          460100    500      5100 -2379 -1492  1858 -3162   518
# ...

# %%
s1 = s

# %%
df
# Out:
#       Unnamed: 0  run_id stress stable block_no  block  trial_no  b1  b2  b3  \
# 0              1      26     no     no      b04      1         1 -10  13  44
# 1              2      26     no     no      b04      1         2  11  11  26
# 2              3      26     no     no      b04      1         3   0   2  20
# 3              4      26     no     no      b04      1         4   3  14  -4
# 4              5      26     no     no      b04      1         5  21  20   9
# ...          ...     ...    ...    ...      ...    ...       ...  ..  ..  ..
# 4795        4796     213     no    yes      b13      4        46 -15  -3  20
# 4796        4797     213     no    yes      b13      4        47 -23 -10  13
# 4797        4798     213     no    yes      b13      4        48 -15  -2   6
# 4798        4799     213     no    yes      b13      4        49 -18  -8   3
# 4799        4800     213     no    yes      b13      4        50 -13  -1   9
#
# ...

# %%
df_1 = df

# %%
f =pd.merge(df_1,final_1)
f
# Out:
#      Unnamed: 0  run_id stress stable block_no  block  trial_no  b1  b2  b3  \
# 0          1801      49     no    yes      b14      1         1 -19   8 -32
# 1          1802      49     no    yes      b14      1         2 -13   9 -25
# 2          1803      49     no    yes      b14      1         3 -19   7 -31
# 3          1804      49     no    yes      b14      1         4 -25  16 -26
# 4          1805      49     no    yes      b14      1         5 -13  21 -30
# ..          ...     ...    ...    ...      ...    ...       ...  ..  ..  ..
# 595        4596     215     no     no      b00      4        46  25  42  70
# 596        4597     215     no     no      b00      4        47  23  29  53
# 597        4598     215     no     no      b00      4        48   3  50  75
# 598        4599     215     no     no      b00      4        49  18  78  62
# 599        4600     215     no     no      b00      4        50  32  74  52
#
# ...

# %%
f.groupby('run_id').count()
# Out:
#         Unnamed: 0  stress  stable  block_no  block  trial_no   b1   b2   b3  \
# run_id
# 49             200     200     200       200    200       200  200  200  200
# 66             200     200     200       200    200       200  200  200  200
# 215            200     200     200       200    200       200  200  200  200
#
#          b4  resp  advantageous  switch  choice  proportion_advchoices  \
# run_id
# 49      200   200           200     196     200                    200
# 66      200   200           200     196     199                    200
# 215     200   200           200     196     199                    200
#
#         switches_in_block  choices  Score
# run_id
# 49                    200      200    200
# 66                    200      200    200
# 215                   200      200    200

# %%
pilot2 = pd.read_csv('pilot_main_p2.csv', usecols = ['response','run_id'])

# %%
pilot2
# Out:
#        run_id                                           response
# 0         118                                                NaN
# 1         118                                                  0
# 2         118  {"age":"18","sex":"Male","hand":"Right","rno":...
# 3         118                                  {"ID":"6776727 "}
# 4         118                                                  0
# ...       ...                                                ...
# 19483      99                                                  0
# 19484      99                                                 -1
# 19485      99                                                NaN
# 19486      99                                                 31
# 19487      99                                                NaN
#
# [19488 rows x 2 columns]

# %%
pilot_2 = pilot2.dropna()

# %%
pilot2[pilot2['response'] == '31']
# Out:
#        run_id response
# 5800      156       31
# 10622      25       31
# 15912      86       31
# 18078      87       31
# 19326      99       31
# 19342      99       31
# 19358      99       31
# 19374      99       31
# 19390      99       31
# 19406      99       31
# 19422      99       31
# 19438      99       31
# 19454      99       31
# 19470      99       31
# 19486      99       31

# %%
def present(string):
    if "ID" in string:
        return True
    else:
        return False

ID1 = pilot_2[pilot_2['response'].apply(present) == True]

def num(string):
    r = "".join([ele for ele in string if ele.isdigit()]) 
    return r
ID1['Random ID'] = ID1['response'].apply(num)
ID1
# Out:
# C:\Users\Saloni\AppData\Local\Temp\ipykernel_20168\2319778123.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ID1['Random ID'] = ID1['response'].apply(num)
#        run_id           response Random ID
# 3         118  {"ID":"6776727 "}   6776727
# 675       103  {"ID":"8988606 "}   8988606
# 1347      115  {"ID":"6929117 "}   6929117
# 2019      116   {"ID":"5457050"}   5457050
# 2691      120  {"ID":"5108791 "}   5108791
# 3363      133   {"ID":"9625737"}   9625737
# 4035      136  {"ID":"8665987 "}   8665987
# 4707      135  {"ID":"7632500 "}   7632500
# 5379      156   {"ID":"7718511"}   7718511
# 6051      146   {"ID":"2929867"}   2929867
# 6723      168   {"ID":"3072680"}   3072680
# 7395      144   {"ID":"5224571"}   5224571
# ...

# %%
ID1.shape
# Out:
# (29, 3)

# %%
score
# Out:
#                     Status                 IPAddress                 Progress  \
# 0            Response Type                IP Address                 Progress
# 1    {"ImportId":"status"}  {"ImportId":"ipAddress"}  {"ImportId":"progress"}
# 2               IP Address              202.3.77.166                      100
# 3               IP Address              202.3.77.166                      100
# 4               IP Address              103.172.8.13                      100
# ..                     ...                       ...                      ...
# 144             IP Address              202.3.77.207                       50
# 145             IP Address             14.139.38.110                       28
# 146             IP Address            106.206.57.106                       11
# 147             IP Address             14.139.38.176                       94
# 148             IP Address             14.139.38.155                       94
#
# ...

# %%
ID_f = pd.concat([ID_1, ID1])
ID_f
# Out:
#        run_id           response Random ID
# 3         116   {"ID":"9220570"}   9220570
# 675       106   {"ID":"1312031"}   1312031
# 1347      104   {"ID":"5537458"}   5537458
# 2019      112   {"ID":"4680581"}   4680581
# 2691      125   {"ID":"5745208"}   5745208
# ...       ...                ...       ...
# 16131      65  {"ID":"5672253 "}   5672253
# 16803      88   {"ID":"2478512"}   2478512
# 17475      87   {"ID":"6023934"}   6023934
# 18147      94   {"ID":"9030445"}   9030445
# 18819      99   {"ID":"7373893"}   7373893
#
# [108 rows x 3 columns]

# %%
final_ = pd.merge(ID_f, score)
final_ = final_[['run_id', 'Score']]

# %%
final_
# Out:
#      run_id  Score
# 0       116   23.0
# 1       104   18.0
# 2       112   19.0
# 3       125   26.0
# 4       120   33.0
# ..      ...    ...
# 96       65   20.0
# 97       88   22.0
# 98       87   20.0
# 99       94   22.0
# 100      99   24.0
#
# [101 rows x 2 columns]

# %%
x = pd.merge(final_,df)
x
# Out:
#      run_id  Score  Unnamed: 0 stress stable block_no  block  trial_no  b1  \
# 0       215    7.0        4401    yes    yes      b12      1         1 -15
# 1       215    7.0        4402    yes    yes      b12      1         2  -9
# 2       215    7.0        4403    yes    yes      b12      1         3  -8
# 3       215    7.0        4404    yes    yes      b12      1         4 -10
# 4       215    7.0        4405    yes    yes      b12      1         5 -18
# ..      ...    ...         ...    ...    ...      ...    ...       ...  ..
# 595      66   31.0        3196     no     no      b04      4        46  21
# 596      66   31.0        3197     no     no      b04      4        47  19
# 597      66   31.0        3198     no     no      b04      4        48  24
# 598      66   31.0        3199     no     no      b04      4        49  30
# 599      66   31.0        3200     no     no      b04      4        50  27
#
# ...

# %%
x.groupby('run_id').count()
# Out:
#         Score  Unnamed: 0  stress  stable  block_no  block  trial_no   b1  \
# run_id
# 49        200         200     200     200       200    200       200  200
# 66        200         200     200     200       200    200       200  200
# 215       200         200     200     200       200    200       200  200
#
#          b2   b3   b4  resp  advantageous  switch  choice  \
# run_id
# 49      200  200  200   200           200     196     200
# 66      200  200  200   200           200     196     199
# 215     200  200  200   200           200     196     199
#
#         proportion_advchoices  switches_in_block  choices
# run_id
# 49                        200                200      200
# 66                        200                200      200
# 215                       200                200      200
